# %% [markdown]
# # Assignment 1

# %% [markdown]
# This project utilizes the ADS509/full_experiment_labels dataset, sourced from the Hugging Face Hub. It is a text classification dataset containing a collection of opinionated text snippets and social commentary, partitioned into standard training, validation, and testing splits (train_data.csv, valid_data.csv, and test_data.csv). The primary objective of this dataset is to facilitate natural language processing (NLP) experiments—specifically by providing raw textual features mapped to corresponding experimental labels. The data has been extracted from its original Parquet format into CSVs to ensure accessibility and reproducibility across the team.

# %%
import pandas as pd 

df = pd.read_csv('../data/train_data.csv')

print("Columns in the dataset:", df.columns.tolist())
print("\nUnique labels:", df['label'].unique()) 
print("\nFirst row preview:\n", df.iloc[0])
# Out:
# Columns in the dataset: ['text', 'label']
#
# Unique labels: [3 2 1 4 0]
#
# First row preview:
#  text     thank you!!!!!!!!!!!
# label                       3
# Name: 0, dtype: object

# %%
df.head()
# Out:
#                                                 text  label
# 0                               thank you!!!!!!!!!!!      3
# 1  of course they are attacking her but are perfe...      2
# 2  i am not aware of the us having the ability in...      1
# 3  these senators are so funny, in the preceding ...      2
# 4  naye face_with_tears_of_joy face_with_tears_of...      3

# %%
print(df['label'].value_counts())
print(df['label'].value_counts(normalize=True))

df['label'].value_counts().plot(kind='bar')
# Out:
# label
# 1    15343
# 3    15333
# 2    11121
# 0     3949
# 4     3522
# Name: count, dtype: int64
# label
# 1    0.311419
# 3    0.311216
# 2    0.225725
# 0    0.080153
# 4    0.071487
# Name: proportion, dtype: float64
# <Axes: xlabel='label'>

# %% [markdown]
# ## Cleanup and Normalization

# %%
print(df['text'])
# Out:
# 0                                     thank you!!!!!!!!!!!
# 1        of course they are attacking her but are perfe...
# 2        i am not aware of the us having the ability in...
# 3        these senators are so funny, in the preceding ...
# 4        naye face_with_tears_of_joy face_with_tears_of...
#                                ...
# 49263    what’s the difference between seizing an oil t...
# 49264    mulberry ([URL] , that perfectly describes new...
# 49265    yeah. under erdogan, turkey's gdp grew like cr...
# 49266                             it should never be funny
# 49267    those sneaky freeloaders, materially improving...
# Name: text, Length: 49268, dtype: object

# %% [markdown]
# Removal of non-alphabetical characters, lowercasing, removing stopwords, and stemming.

# %%
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

corpus = []
ps = PorterStemmer()
sw = set(stopwords.words('english'))
for i in range(0, df['text'].size):
    # get review and remove non alpha chars
    review = re.sub('[^a-zA-Z]', ' ', df['text'][i])
    # to lower-case
    review = review.lower()
    # split into tokens, apply stemming and remove stop words
    review = ' '.join([ps.stem(w) for w in review.split() if w not in sw])
    corpus.append(review)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/nltk/corpus/util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File ~/.local/lib/python3.10/site-packages/nltk/data.py:579, in find(resource_name, paths)
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - '/home/pedro/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[1], line 7
#       5 corpus = []
#       6 ps = PorterStemmer()
# ----> 7 sw = set(stopwords.words('english'))
#       8 for i in range(0, df['text'].size):
#       9     # get review and remove non alpha chars
#      10     review = re.sub('[^a-zA-Z]', ' ', df['text'][i])
#
# File ~/.local/lib/python3.10/site-packages/nltk/corpus/util.py:120, in LazyCorpusLoader.__getattr__(self, attr)
#     117 if attr == "__bases__":
#     118     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 120 self.__load()
#     121 # This looks circular, but its not, since __load() changes our
#     122 # __class__ to something new:
#     123 return getattr(self, attr)
#
# File ~/.local/lib/python3.10/site-packages/nltk/corpus/util.py:86, in LazyCorpusLoader.__load(self)
#      84             root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85         except LookupError:
# ---> 86             raise e
#      88 # Load the corpus.
#      89 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#
# File ~/.local/lib/python3.10/site-packages/nltk/corpus/util.py:81, in LazyCorpusLoader.__load(self)
#      79 else:
#      80     try:
# ---> 81         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82     except LookupError as e:
#      83         try:
#
# File ~/.local/lib/python3.10/site-packages/nltk/data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords
#
#   Searched in:
#     - '/home/pedro/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %% [markdown]
# #### Wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud().generate(" ".join(corpus))

plt.figure()
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# Wordcloud for each label.

# %%
label_names = {
    0: 'Neutral',
    1: 'Opinion',
    2: 'Argumentative',
    3: 'Expressive',
    4: 'Informational'
}

texts_by_label = {
    label: ' '.join([review for review, y in zip(corpus, df['label']) if y == label])
    for label in label_names
}

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

for i, (label, name) in enumerate(label_names.items()):
    text = texts_by_label[label]
    if text.strip():
        wc = WordCloud(background_color='white').generate(text)
        axes[i].imshow(wc)
    else:
        axes[i].text(0.5, 0.5, 'No data for this label', ha='center', va='center')
    axes[i].set_title(f"{name} ({label})")
    axes[i].axis('off')

# Hide the unused subplot (6th axis)
for j in range(len(label_names), len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Generating Data Set

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(max_features = 1500)
X = vectorizer.fit_transform(corpus).toarray()
y = df['label']

print(X.shape, y.shape)
# Out:
# (49268, 1500) (49268,)

# %%
idx = 100  # 124th review (0-based index)

print('Original review:')
print(df['text'][idx])
print('\nPreprocessed review:')
print(corpus[idx])

print('\nBag-of-Words vector (full):')
print(X[idx])

feature_names = vectorizer.get_feature_names_out()
non_zero_indices = [j for j, v in enumerate(X[idx]) if v > 0]

print('\nNon-zero features in the 124th review:')
for j in non_zero_indices:
    print(f"{feature_names[j]}: {X[idx][j]}")
# Out:
# Original review:
# so even autocomplete is smart enough to understand that "not politically correct" just means racism
#
# Preprocessed review:
# even autocomplet smart enough understand polit correct mean racism
#
# Bag-of-Words vector (full):
# [0 0 0 ... 0 0 0]
#
# Non-zero features in the 124th review:
# correct: 1
# enough: 1
# even: 1
# mean: 1
# polit: 1
# racism: 1
# smart: 1
# understand: 1

# %% [markdown]
# ## Training Classifiers

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

print("\nLabel distribution in the training set:")
print(y_train.value_counts())

print("\nLabel distribution in the test set:")
print(y_test.value_counts())
# Out:
# (39414, 1500) (39414,)
# (9854, 1500) (9854,)
#
# Label distribution in the training set:
# label
# 3    12317
# 1    12285
# 2     8895
# 0     3116
# 4     2801
# Name: count, dtype: int64
#
# Label distribution in the test set:
# label
# 1    3058
# 3    3016
# 2    2226
# 0     833
# 4     721
# Name: count, dtype: int64

# %% [markdown]
# #### Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB()
clf.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = clf.predict(X_test)
print(y_pred)
# Out:
# [1 4 3 ... 4 2 1]

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

# confusion matrix
print(confusion_matrix(y_test, y_pred))

# multiclass metrics
print('Accuracy: ', accuracy_score(y_test, y_pred))
print('Precision (weighted):', precision_score(y_test, y_pred, average='weighted', zero_division=0))
print('Recall (weighted):   ', recall_score(y_test, y_pred, average='weighted', zero_division=0))
print('F1 (weighted):       ', f1_score(y_test, y_pred, average='weighted', zero_division=0))

print('\nClassification Report:')
print(classification_report(y_test, y_pred, target_names=['Neutral', 'Opinion', 'Argumentative', 'Expressive', 'Informational'], zero_division=0))
# Out:
# [[  92  325  186  171   59]
#  [ 111 1818  677  400   52]
#  [ 115  748 1155   54  154]
#  [  83 1010  216 1666   41]
#  [  57  154  175   63  272]]
# Accuracy:  0.5077126040186726
# Precision (weighted): 0.5154667938981629
# Recall (weighted):    0.5077126040186726
# F1 (weighted):        0.503818066569574
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Neutral       0.20      0.11      0.14       833
#       Opinion       0.45      0.59      0.51      3058
# Argumentative       0.48      0.52      0.50      2226
#    Expressive       0.71      0.55      0.62      3016
# Informational       0.47      0.38      0.42       721
#
#      accuracy                           0.51      9854
#     macro avg       0.46      0.43      0.44      9854
#  weighted avg       0.52      0.51      0.50      9854

# %%
import pandas as pd
import numpy as np
import spacy
import time
import os
import gensim.downloader as api
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, HashingVectorizer
from sklearn.decomposition import TruncatedSVD, LatentDirichletAllocation
from sklearn.linear_model import LogisticRegression, PassiveAggressiveClassifier
from sklearn.svm import SVC
from sklearn.multiclass import OneVsRestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from hmmlearn import hmm
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.svm import LinearSVC

# ---------------------------------------------------------
# 1. Custom Transformers for Advanced Features
# ---------------------------------------------------------

class LinguisticFeatureExtractor(BaseEstimator, TransformerMixin):
    """Extracts style and linguistic features (punctuation, length, caps)."""
    def fit(self, X, y=None):
        return self
        
    def transform(self, X):
        features = []
        for text in X:
            length = len(text)
            exclamations = text.count('!')
            questions = text.count('?')
            caps = sum(1 for c in text if c.isupper())
            words = len(text.split())
            
            features.append([
                length, 
                words, 
                exclamations / max(length, 1), 
                questions / max(length, 1), 
                caps / max(length, 1)
            ])
        return np.array(features)

class DenseEmbeddingTransformer(BaseEstimator, TransformerMixin):
    """Loads pre-trained Word2Vec or FastText and averages them per document in FAST BATCHES."""
    def __init__(self, model_type='word2vec'):
        self.model_type = model_type
        self.nlp = None
        
    def fit(self, X, y=None):
        if self.nlp is None:
            # OPTIMIZATION: Disable the parser, NER, and lemmatizer. We only want the raw vectors!
            self.nlp = spacy.load("en_core_web_md", disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer", "ner"])
        return self
        
    def transform(self, X):
        # OPTIMIZATION: Use .pipe() to process 500 tweets at the exact same time in C-optimized batches
        return np.array([doc.vector for doc in self.nlp.pipe(X, batch_size=500)])

class HMMClassifierWrapper(BaseEstimator):
    """Wraps hmmlearn to work within a scikit-learn pipeline for 5 classes."""
    def __init__(self, n_components=5):
        self.n_components = n_components
        self.models = {}
        
    def fit(self, X, y):
        classes = np.unique(y)
        for c in classes:
            X_c = X[y == c]
            model = hmm.GaussianHMM(n_components=self.n_components, covariance_type="diag", n_iter=10)
            if X_c.shape[0] > 0:
                model.fit(X_c)
                self.models[c] = model
        return self
        
    def predict(self, X):
        predictions = []
        for sample in X:
            sample = sample.reshape(1, -1)
            scores = {c: model.score(sample) for c, model in self.models.items()}
            predictions.append(max(scores, key=scores.get))
        return np.array(predictions)

# ---------------------------------------------------------
# 2. The Configuration Matrix
# ---------------------------------------------------------

VALID_COMBINATIONS = {
    'LogReg':      {'BoW': True, 'TFIDF': True, 'NGrams': True, 'Hashing': True, 'LSA': True, 'Word2Vec': True, 'FastText': True, 'Linguistic': True},
    'SVM_OvR':     {'BoW': True, 'TFIDF': True, 'NGrams': True, 'Hashing': True, 'LSA': True, 'Word2Vec': True, 'FastText': True, 'Linguistic': True},
    'NaiveBayes':  {'BoW': True, 'TFIDF': True, 'NGrams': True, 'Hashing': True, 'LSA': False, 'Word2Vec': False, 'FastText': False, 'Linguistic': False},
    'SentimentLDA':{'BoW': True, 'TFIDF': False, 'NGrams': True, 'Hashing': False, 'LSA': False, 'Word2Vec': False, 'FastText': False, 'Linguistic': False},
    'HMM':         {'BoW': True, 'TFIDF': False, 'NGrams': True, 'Hashing': False, 'LSA': False, 'Word2Vec': False, 'FastText': False, 'Linguistic': True},
    'kNN':         {'BoW': False, 'TFIDF': True, 'NGrams': False, 'Hashing': False, 'LSA': True, 'Word2Vec': True, 'FastText': True, 'Linguistic': True},
    'XGBoost':     {'BoW': True, 'TFIDF': True, 'NGrams': True, 'Hashing': True, 'LSA': True, 'Word2Vec': True, 'FastText': True, 'Linguistic': True},
    'AdaBoost':    {'BoW': False, 'TFIDF': True, 'NGrams': False, 'Hashing': True, 'LSA': True, 'Word2Vec': True, 'FastText': True, 'Linguistic': True}
}

# ---------------------------------------------------------
# 3. Component Factories
# ---------------------------------------------------------

def get_feature_extractor(feature_name):
    if feature_name == 'BoW': return CountVectorizer(dtype=np.float64)
    elif feature_name == 'TFIDF': return TfidfVectorizer()
    elif feature_name == 'NGrams': return TfidfVectorizer(ngram_range=(1, 3))
    elif feature_name == 'Hashing': return HashingVectorizer(n_features=10000) 
    elif feature_name == 'LSA': return Pipeline([('tfidf', TfidfVectorizer()), ('svd', TruncatedSVD(n_components=100))])
    elif feature_name == 'Word2Vec': return DenseEmbeddingTransformer(model_type='word2vec')
    elif feature_name == 'FastText': return DenseEmbeddingTransformer(model_type='fasttext')
    elif feature_name == 'Linguistic': return Pipeline([('linguistic', LinguisticFeatureExtractor()), ('scaler', StandardScaler())])

def get_classifier(model_name):
    if model_name == 'LogReg': return LogisticRegression(max_iter=1000, n_jobs=-1)
    elif model_name == 'SVM_OvR': return OneVsRestClassifier(LinearSVC(max_iter=1000, dual=False), n_jobs=-1)
    elif model_name == 'NaiveBayes': return MultinomialNB() 
    elif model_name == 'SentimentLDA':
        return Pipeline([('lda', LatentDirichletAllocation(n_components=5, n_jobs=-1)), ('clf', LogisticRegression(n_jobs=-1))])
    elif model_name == 'HMM': return HMMClassifierWrapper() 
    elif model_name == 'kNN': return KNeighborsClassifier(n_neighbors=5, metric='cosine', n_jobs=-1)
    elif model_name == 'XGBoost':
        return XGBClassifier(objective='multi:softmax', num_class=5, n_jobs=-1, tree_method='hist', device='cuda')
    elif model_name == 'AdaBoost': return AdaBoostClassifier() 

# ---------------------------------------------------------
# 4. Main Execution Loop
# ---------------------------------------------------------

def run_pipeline():
    output_filename = "pipeline_results.csv"
    
    # --- CHECKPOINT LOGIC: Load completed combinations ---
    completed_combos = set()
    if os.path.exists(output_filename):
        try:
            existing_df = pd.read_csv(output_filename)
            # Create a set of (Model, Feature) tuples that are already done
            completed_combos = set(zip(existing_df['Model'], existing_df['Feature']))
            print(f"[INFO] Found existing checkpoint file. Resuming... ({len(completed_combos)} models already completed)")
        except Exception as e:
            print(f"[WARNING] Could not read existing results: {e}. Starting fresh.")

    print("Loading data...")
    train_df = pd.read_csv('../data/train_data.csv')
    valid_df = pd.read_csv('../data/valid_data.csv')
    
    X_train, y_train = train_df['text'], train_df['label']
    X_valid, y_valid = valid_df['text'], valid_df['label']

    for model_name, features in VALID_COMBINATIONS.items():
        for feature_name, is_valid in features.items():
            if not is_valid:
                continue 
            
            # --- CHECKPOINT LOGIC: Skip if already done ---
            if (model_name, feature_name) in completed_combos:
                print(f"--- SKIPPING: [{model_name}] with [{feature_name}] (Already run) ---")
                continue
                
            print(f"--- Training: [{model_name}] with [{feature_name}] ---")
            
            try:
                extractor = get_feature_extractor(feature_name)
                classifier = get_classifier(model_name)
                
                if model_name == 'NaiveBayes' and feature_name == 'Hashing':
                    pipeline = Pipeline([
                        ('feature', extractor),
                        ('to_dense', FunctionTransformer(lambda x: np.abs(x.toarray()), accept_sparse=True)),
                        ('clf', classifier)
                    ])
                elif model_name == 'HMM' and feature_name in ['BoW', 'NGrams']:
                    pipeline = Pipeline([
                        ('feature', extractor),
                        ('to_dense', FunctionTransformer(lambda x: x.toarray(), accept_sparse=True)),
                        ('clf', classifier)
                    ])
                elif feature_name == 'LSA' and model_name in ['XGBoost', 'AdaBoost', 'NaiveBayes']:
                     pipeline = Pipeline([('feature', extractor), ('clf', classifier)])
                else:
                    pipeline = Pipeline([('feature', extractor), ('clf', classifier)])

                # Train Timer
                start_train = time.time()
                pipeline.fit(X_train, y_train)
                end_train = time.time()
                train_time = end_train - start_train
                
                # Predict Timer
                start_pred = time.time()
                y_pred = pipeline.predict(X_valid)
                end_pred = time.time()
                val_time = end_pred - start_pred
                
                # Metrics Calculation
                acc = accuracy_score(y_valid, y_pred)
                precision, recall, f1, _ = precision_recall_fscore_support(
                    y_valid, y_pred, average='weighted', zero_division=0
                )
                
                print(f"Success! F1 Score: {f1:.4f} | Acc: {acc:.4f} | Total Time: {(train_time + val_time):.2f}s\n")
                
                new_result = {
                    'Model': model_name,
                    'Feature': feature_name,
                    'F1_Score': round(f1, 4),      
                    'Accuracy': round(acc, 4),     
                    'Precision': round(precision, 4),
                    'Recall': round(recall, 4),
                    'Train_Time_sec': round(train_time, 4),
                    'Val_Time_sec': round(val_time, 4),
                    'Total_Time_sec': round(train_time + val_time, 4)
                }
                
                # --- CHECKPOINT LOGIC: Save immediately to CSV ---
                new_df = pd.DataFrame([new_result])
                # If file doesn't exist yet, add headers. If it does, just append the row.
                write_mode = 'a' if os.path.exists(output_filename) else 'w'
                write_header = not os.path.exists(output_filename)
                new_df.to_csv(output_filename, mode=write_mode, header=write_header, index=False)
                
            except Exception as e:
                print(f"FAILED. Error: {str(e)}\n")

    # --- FINAL CLEANUP: Sort everything after all runs are completely done ---
    if os.path.exists(output_filename):
        final_df = pd.read_csv(output_filename).sort_values(by='F1_Score', ascending=False)
        final_df.to_csv(output_filename, index=False) # Overwrite with the nicely sorted version
        
        print("=== FINAL RANKINGS ===")
        print(final_df[['Model', 'Feature', 'F1_Score', 'Accuracy', 'Total_Time_sec']].head(10).to_string(index=False))
        print(f"\n[INFO] Full detailed results successfully saved to {output_filename}")

if __name__ == "__main__":
    run_pipeline()
# Out:
# [INFO] Found existing checkpoint file. Resuming... (1 models already completed)
# Loading data...
# --- SKIPPING: [LogReg] with [BoW] (Already run) ---
# --- Training: [LogReg] with [TFIDF] ---
# Success! F1 Score: 0.6289 | Acc: 0.6380 | Total Time: 20.29s
#
# --- Training: [LogReg] with [NGrams] ---
# Success! F1 Score: 0.5937 | Acc: 0.6116 | Total Time: 354.79s
#
# --- Training: [LogReg] with [Hashing] ---
# Success! F1 Score: 0.6262 | Acc: 0.6361 | Total Time: 12.05s
#
# --- Training: [LogReg] with [LSA] ---
# Success! F1 Score: 0.5702 | Acc: 0.5872 | Total Time: 15.24s
#
# --- Training: [LogReg] with [Word2Vec] ---
# Success! F1 Score: 0.5130 | Acc: 0.5291 | Total Time: 67.25s
#
# --- Training: [LogReg] with [FastText] ---
# Success! F1 Score: 0.5130 | Acc: 0.5291 | Total Time: 65.25s
#
# --- Training: [LogReg] with [Linguistic] ---
# Success! F1 Score: 0.5082 | Acc: 0.5337 | Total Time: 2.57s
#
# --- Training: [SVM_OvR] with [BoW] ---
# FAILED. Error: WRITEBACKIFCOPY base is read-only
#
# --- Training: [SVM_OvR] with [TFIDF] ---
# Success! F1 Score: 0.6129 | Acc: 0.6189 | Total Time: 8.22s
#
# --- Training: [SVM_OvR] with [NGrams] ---
# Success! F1 Score: 0.6003 | Acc: 0.6131 | Total Time: 31.42s
#
# --- Training: [SVM_OvR] with [Hashing] ---
# Success! F1 Score: 0.6093 | Acc: 0.6183 | Total Time: 3.78s
#
# --- Training: [SVM_OvR] with [LSA] ---
# Success! F1 Score: 0.5569 | Acc: 0.5823 | Total Time: 9.09s
#
# --- Training: [SVM_OvR] with [Word2Vec] ---
# Success! F1 Score: 0.4980 | Acc: 0.5262 | Total Time: 33.05s
#
# --- Training: [SVM_OvR] with [FastText] ---
# Success! F1 Score: 0.4980 | Acc: 0.5262 | Total Time: 32.47s
#
# --- Training: [SVM_OvR] with [Linguistic] ---
# Success! F1 Score: 0.4789 | Acc: 0.5094 | Total Time: 1.01s
#
# --- Training: [NaiveBayes] with [BoW] ---
# Success! F1 Score: 0.5293 | Acc: 0.5482 | Total Time: 1.43s
#
# --- Training: [NaiveBayes] with [TFIDF] ---
# Success! F1 Score: 0.5082 | Acc: 0.5466 | Total Time: 1.52s
#
# --- Training: [NaiveBayes] with [NGrams] ---
# Success! F1 Score: 0.4739 | Acc: 0.5117 | Total Time: 11.06s
#
# --- Training: [NaiveBayes] with [Hashing] ---
# Success! F1 Score: 0.5136 | Acc: 0.5481 | Total Time: 12.90s
#
# --- Training: [SentimentLDA] with [BoW] ---
# Success! F1 Score: 0.4632 | Acc: 0.5044 | Total Time: 60.05s
#
# --- Training: [SentimentLDA] with [NGrams] ---
# Success! F1 Score: 0.2356 | Acc: 0.3086 | Total Time: 73.95s
#
# --- Training: [HMM] with [BoW] ---
# FAILED. Error: A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array.
#
# --- Training: [HMM] with [NGrams] ---
# FAILED. Error: A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array.
#
# --- Training: [HMM] with [Linguistic] ---
# Success! F1 Score: 0.4258 | Acc: 0.4647 | Total Time: 14.76s
#
# --- Training: [kNN] with [TFIDF] ---
# Success! F1 Score: 0.4977 | Acc: 0.5066 | Total Time: 21.40s
#
# --- Training: [kNN] with [LSA] ---
# Success! F1 Score: 0.5180 | Acc: 0.5241 | Total Time: 35.59s
#
# --- Training: [kNN] with [Word2Vec] ---
# Success! F1 Score: 0.4399 | Acc: 0.4652 | Total Time: 36.74s
#
# --- Training: [kNN] with [FastText] ---
# Success! F1 Score: 0.4399 | Acc: 0.4652 | Total Time: 31.26s
#
# --- Training: [kNN] with [Linguistic] ---
# Success! F1 Score: 0.5166 | Acc: 0.5262 | Total Time: 14.46s
#
# --- Training: [XGBoost] with [BoW] ---
# C:\Users\Utilizador\anaconda3\Lib\site-packages\xgboost\core.py:729: UserWarning: [19:41:56] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\common\error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# Success! F1 Score: 0.3766 | Acc: 0.4299 | Total Time: 5.03s
#
# --- Training: [XGBoost] with [TFIDF] ---
# Success! F1 Score: 0.0099 | Acc: 0.0729 | Total Time: 7.45s
#
# --- Training: [XGBoost] with [NGrams] ---
# Success! F1 Score: 0.1562 | Acc: 0.3124 | Total Time: 103.27s
#
# --- Training: [XGBoost] with [Hashing] ---
# Success! F1 Score: 0.5995 | Acc: 0.6129 | Total Time: 22.26s
#
# --- Training: [XGBoost] with [LSA] ---
# Success! F1 Score: 0.5848 | Acc: 0.5976 | Total Time: 10.63s
#
# --- Training: [XGBoost] with [Word2Vec] ---
# Success! F1 Score: 0.5824 | Acc: 0.5992 | Total Time: 25.61s
#
# --- Training: [XGBoost] with [FastText] ---
# Success! F1 Score: 0.5824 | Acc: 0.5992 | Total Time: 26.52s
#
# --- Training: [XGBoost] with [Linguistic] ---
# Success! F1 Score: 0.5610 | Acc: 0.5744 | Total Time: 2.97s
#
# --- Training: [AdaBoost] with [TFIDF] ---
# Success! F1 Score: 0.5509 | Acc: 0.5653 | Total Time: 14.35s
#
# --- Training: [AdaBoost] with [Hashing] ---
# Success! F1 Score: 0.5483 | Acc: 0.5610 | Total Time: 11.66s
#
# --- Training: [AdaBoost] with [LSA] ---
# Success! F1 Score: 0.5299 | Acc: 0.5502 | Total Time: 53.48s
#
# --- Training: [AdaBoost] with [Word2Vec] ---
# Success! F1 Score: 0.5195 | Acc: 0.5403 | Total Time: 176.37s
#
# --- Training: [AdaBoost] with [FastText] ---

# %%
# !pip install pandas scikit-learn xgboost gensim spacy hmmlearn
# Out:
# Requirement already satisfied: pandas in c:\users\utilizador\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: scikit-learn in c:\users\utilizador\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: xgboost in c:\users\utilizador\anaconda3\lib\site-packages (3.0.2)
# Requirement already satisfied: gensim in c:\users\utilizador\anaconda3\lib\site-packages (4.3.0)
# Collecting spacy
#   Obtaining dependency information for spacy from https://files.pythonhosted.org/packages/9b/13/a542ac9b61d071f3328fda1fd8087b523fb7a4f2c340010bc70b1f762485/spacy-3.8.11-cp311-cp311-win_amd64.whl.metadata
#   Using cached spacy-3.8.11-cp311-cp311-win_amd64.whl.metadata (28 kB)
# Collecting hmmlearn
#   Obtaining dependency information for hmmlearn from https://files.pythonhosted.org/packages/c8/5f/65b892737fed694b23a753b516cd851d21963abd33ea86123723f6279987/hmmlearn-0.3.3-cp311-cp311-win_amd64.whl.metadata
#   Using cached hmmlearn-0.3.3-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\utilizador\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\utilizador\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\utilizador\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\utilizador\anaconda3\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\utilizador\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\utilizador\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\utilizador\anaconda3\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\utilizador\anaconda3\lib\site-packages (from gensim) (5.2.1)
#
0-py3-none-any.whl.metadata (4.8 kB)
# Collecting fst-pso==1.8.1 (from pyfume->FuzzyTM>=0.4.0->gensim)
#   Using cached fst_pso-1.8.1-py3-none-any.whl
# Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/da/6d/1235da14daddaa6e47f74ba0c255358f0ce7a6ee05da8bf8eb49161aa6b5/pandas-1.5.3-cp311-cp311-win_amd64.whl.metadata
#   Using cached pandas-1.5.3-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting miniful (from fst-pso==1.8.1->pyfume->FuzzyTM>=0.4.0->gensim)
#   Using cached miniful-0.0.6-py3-none-any.whl
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\utilizador\anaconda3\lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\utilizador\anaconda3\lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\utilizador\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.1.0)
# Using cached spacy-3.8.11-cp311-cp311-win_amd64.whl (15.3 MB)
# Using cached hmmlearn-0.3.3-cp311-cp311-win_amd64.whl (127 kB)
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Using cached cymem-2.0.13-cp311-cp311-win_amd64.whl (40 kB)
# Using cached FuzzyTM-2.0.9-py3-none-any.whl (31 kB)
# Using cached murmurhash-1.0.15-cp311-cp311-win_amd64.whl (25 kB)
# Using cached preshed-3.0.12-cp311-cp311-win_amd64.whl (117 kB)
# Using cached srsly-2.5.2-cp311-cp311-win_amd64.whl (654 kB)
# Using cached thinc-8.3.11-cp311-cp311-win_amd64.whl (1.8 MB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp311-cp311-win_amd64.whl (2.0 MB)
# Using cached typer_slim-0.24.0-py3-none-any.whl (3.4 kB)
# Using cached weasel-0.4.3-py3-none-any.whl (50 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached blis-1.3.3-cp311-cp311-win_amd64.whl (6.2 MB)
# Using cached cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Using cached typer-0.24.1-py3-none-any.whl (56 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached pyFUME-0.3.4-py3-none-any.whl (60 kB)
# Using cached pandas-1.5.3-cp311-cp311-win_amd64.whl (10.3 MB)
# Using cached scipy-1.10.1-cp311-cp311-win_amd64.whl (42.2 MB)
# Using cached simpful-2.12.0-py3-none-any.whl (24 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached rich-14.3.3-py3-none-any.whl (310 kB)
# Installing collected packages: typing-inspection, scipy, pydantic-core, murmurhash, cymem, cloudpathlib, click, catalogue, blis, annotated-types, annotated-doc, srsly, simpful, rich, pydantic, preshed, pandas, miniful, typer, hmmlearn, fst-pso, confection, typer-slim, thinc, pyfume, weasel, FuzzyTM, spacy
# Successfully installed FuzzyTM-2.0.9 annotated-doc-0.0.4 annotated-types-0.7.0 blis-1.3.3 catalogue-2.0.10 click-8.3.1 cloudpathlib-0.23.0 confection-0.1.5 cymem-2.0.13 fst-pso-1.8.1 hmmlearn-0.3.3 miniful-0.0.6 murmurhash-1.0.15 pandas-1.5.3 preshed-3.0.12 pydantic-2.12.5 pydantic-core-2.41.5 pyfume-0.3.4 rich-14.3.3 scipy-1.10.1 simpful-2.12.0 spacy-3.8.11 srsly-2.5.2 thinc-8.3.11 typer-0.24.1 typer-slim-0.24.0 typing-inspection-0.4.2 weasel-0.4.3
#   WARNING: The script typer.exe is installed in 'C:\Users\Utilizador\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script weasel.exe is installed in 'C:\Users\Utilizador\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script spacy.exe is installed in 'C:\Users\Utilizador\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-cloud-auth 0.1.3 requires pydantic<2.0, but you have pydantic 2.12.5 which is incompatible.
# python-lsp-black 1.2.1 requires black>=22.3.0, but you have black 0.0 which is incompatible.

# %%
import sys
# !{sys.executable} -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.8.0/en_core_web_md-3.8.0-py3-none-any.whl (33.5 MB)
#      